# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import map_coordinates
from scipy.ndimage import gaussian_filter
from tqdm import tqdm
import os
# Out:
# 2024-12-15 23:27:12.036107: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1734323232.050899 4083201 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1734323232.055480 4083201 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-15 23:27:12.071477: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
tf.config.set_visible_devices(tf.config.experimental.list_physical_devices('GPU')[1], 'GPU')

# Check which GPU is being used
logical_gpus = tf.config.experimental.list_logical_devices('GPU')
print(logical_gpus)
# Out:
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# I0000 00:00:1734323237.642666 4083201 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1024 MB memory:  -> device: 1, name: NVIDIA A40, pci bus id: 0000:23:00.0, compute capability: 8.6

# %%
# Load MNIST dataset
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
def batch_elastic_transform(images, sigma, alpha, height, width, random_state=None):
    """
    Elastic deformation of images as described in [Simard 2003].
    
    Args:
        images: a two-dimensional numpy array; list of flattened images
        sigma: variance of the gaussian kernel
        alpha: multiplier for the displacement fields
        height: image height
        width: image width
        random_state: numpy random state object
    
    Returns:
        elastically distorted images of the same shape
    """
    assert len(images.shape) == 2
    e_images = np.empty_like(images)
    e_images[:] = images
    
    e_images = e_images.reshape(-1, height, width)
    
    if random_state is None:
        random_state = np.random.RandomState(None)
    x, y = np.mgrid[0:height, 0:width]
    
    for i in range(e_images.shape[0]):
        dx = gaussian_filter((random_state.rand(height, width) * 2 - 1), 
                           sigma, mode='constant') * alpha
        dy = gaussian_filter((random_state.rand(height, width) * 2 - 1), 
                           sigma, mode='constant') * alpha
        indices = x + dx, y + dy
        e_images[i] = map_coordinates(e_images[i], indices, order=1)

    return e_images.reshape(-1, height*width)

# %%
random_state = np.random.RandomState(None)
dx1 = random_state.rand(28, 28) * 2 - 1
dy1 = random_state.rand(28, 28) * 2 - 1
dx2 = gaussian_filter(dx1, 4, mode='constant')
dy2 = gaussian_filter(dy1, 4, mode='constant')

# %%
x, y = np.mgrid[0:28, 0:28]
    
plt.figure(figsize=(12, 4))
plt.subplot(131)
plt.quiver(x, y, dx1, dy1)
plt.title('Before Gaussian Filter')
plt.subplot(132)
plt.quiver(x, y, dx2, dy2)
plt.title('After Gaussian Filter')
# Demonstrate elastic transform on MNIST image
img = x_train[0]
plt.subplot(133)
plt.imshow(img, cmap='gray')
plt.title('Original Image')
plt.show()

# %%
transformed_img = batch_elastic_transform(
    img.reshape(1, -1), 
    sigma=4, 
    alpha=20, 
    height=28, 
    width=28
)
    
plt.figure(figsize=(4, 4))
plt.imshow(transformed_img.reshape(28, 28), cmap='gray')
plt.title('Transformed Image')
plt.show()

# %%
def transform_dataset(x_train, batch_size=1000, sigma=4, alpha=20):
    """
    Transform entire dataset in batches to avoid memory issues
    """
    height, width = x_train.shape[1:]
    n_samples = x_train.shape[0]
    
    # Initialize array for transformed images
    transformed_images = np.zeros((n_samples, height * width))
    
    # Process in batches
    for i in tqdm(range(0, n_samples, batch_size)):
        batch_end = min(i + batch_size, n_samples)
        batch = x_train[i:batch_end]
        
        # Reshape batch to 2D array (n_samples, pixels)
        batch_flat = batch.reshape(batch_end - i, -1)
        
        # Apply transformation
        transformed = batch_elastic_transform(
            batch_flat, 
            sigma=sigma, 
            alpha=alpha,
            height=height,
            width=width
        )
        
        transformed_images[i:batch_end] = transformed
    
    return transformed_images

# %%
transformed_train = transform_dataset(x_train)
# Out:
# 100%|██████████| 60/60 [00:09<00:00,  6.13it/s]

# %%
def plot_comparison(original, transformed, num_images=5):
    plt.figure(figsize=(2*num_images, 4))
    
    for i in range(num_images):
        # Original image
        plt.subplot(2, num_images, i + 1)
        plt.imshow(original[i], cmap='gray')
        plt.axis('off')
        if i == 0:
            plt.title('Original')
            
        # Transformed image
        plt.subplot(2, num_images, num_images + i + 1)
        plt.imshow(transformed[i].reshape(28, 28), cmap='gray')
        plt.axis('off')
        if i == 0:
            plt.title('Transformed')
    
    plt.tight_layout()
    plt.show()

# Plot some examples
plot_comparison(x_train, transformed_train)

# %%
class AttentionAutoencoder(tf.keras.Model):
    def __init__(self, input_shape, n_classes, **kwargs):
        super(AttentionAutoencoder, self).__init__(**kwargs)
        self.input_shape_ = input_shape
        self.n_classes = n_classes
        
        # Encoder layers
        self.encoder = tf.keras.Sequential([
            tf.keras.layers.InputLayer(input_shape=input_shape),
            tf.keras.layers.Conv2D(32, 3, strides=2, padding='same', activation='relu'),
            tf.keras.layers.Conv2D(32, 3, strides=2, padding='same', activation='relu'),
            tf.keras.layers.Conv2D(32, 3, strides=2, padding='same', activation='relu'),
            tf.keras.layers.Conv2D(10, 3, strides=1, padding='same', activation='relu'),
            tf.keras.layers.Flatten()
        ])

        self.downsize = tf.keras.layers.Dense(15)
        # Attention layers
        self.attention = tf.keras.layers.Attention()
        self.query_dense = tf.keras.layers.Dense(15)
        self.value_dense = tf.keras.layers.Dense(15)
        
        # Decoder layers
        self.decoder = tf.keras.Sequential([
            tf.keras.layers.InputLayer(shape=(15,)),
            tf.keras.layers.Dense(4*4*10),
            tf.keras.layers.Reshape((4, 4, 10)),
            tf.keras.layers.Conv2DTranspose(32, 3, strides=1, padding='valid', activation='relu'),  # 4x4x32
            tf.keras.layers.Conv2DTranspose(32, 3, strides=2, padding='same', activation='relu'),  # 8x8x32
            tf.keras.layers.Conv2DTranspose(32, 3, strides=1, padding='valid', activation='relu'),  # 14x14x32
            tf.keras.layers.Conv2DTranspose(1, 3, strides=2, padding='same', activation='sigmoid') # 28x28x1
        ])
        
        # Classification layer
        self.classifier = tf.keras.layers.Dense(n_classes)

        print(self.encoder.summary())
        print(self.decoder.summary())


    def call(self, inputs):
        # Ensure input shape is correct
        if len(inputs.shape) == 2:
            inputs = tf.reshape(inputs, [-1, 28, 28, 1])
            
        # Encode
        features = self.downsize(self.encoder(inputs))
        query = self.query_dense(features)
        value = self.value_dense(features)

        query = tf.expand_dims(query, axis=1)
        value = tf.expand_dims(value, axis=1)

        # Apply attention
        attention_output = self.attention([query, value])
        attention_weights = tf.matmul(query, tf.transpose(value, [0, 2, 1]))
        attention_weights = tf.nn.softmax(attention_weights)
        
        attended_features = tf.squeeze(attention_output, axis=1)
        
        # Get logits
        logits = self.classifier(attended_features)
        
        # Decode
        decoded = self.decoder(features)
        
        return logits, decoded, features, attended_features, attention_weights

    def get_config(self):
        config = super(AttentionAutoencoder, self).get_config()
        config.update({
            "input_shape": self.input_shape_,
            "n_classes": self.n_classes,
        })
        return config

    @classmethod
    def from_config(cls, config):
        input_shape = config.pop("input_shape", (28, 28, 1))  
        n_classes = config.pop("n_classes", 10)           
        return cls(input_shape=input_shape, n_classes=n_classes, **config)

# %%
def train_step(model, optimizer, x, y, lambda_params):
    with tf.GradientTape() as tape:
        # Forward pass
        x = tf.reshape(x, [-1, 28, 28, 1])
        logits, decoded, features, attended_features, attention_weights = model(x)

        # Calculate losses
        y = tf.reshape(y, [-1, 10])
        classification_loss = tf.reduce_mean(
            tf.keras.losses.categorical_crossentropy(y, logits, from_logits=True)
        )
        x_flat = tf.reshape(x, [-1, 784])
        decoded_flat = tf.reshape(decoded, [-1, 784])
        
        reconstruction_loss = tf.reduce_mean(
            tf.keras.losses.binary_crossentropy(x_flat, decoded_flat)
        )
        
        # Attention diversity loss - encourages diverse attention patterns
        kl_loss = tf.keras.losses.KLDivergence()
        uniform_dist = tf.ones_like(attention_weights) / tf.cast(tf.shape(attention_weights)[1], tf.float32)
        attention_loss = kl_loss(uniform_dist, attention_weights)
        
        # Total loss
        total_loss = (lambda_params['class'] * classification_loss + 
                     lambda_params['ae'] * reconstruction_loss +
                     lambda_params['attention'] * attention_loss)
    
    # Backpropagation
    gradients = tape.gradient(total_loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return {
        'classification': classification_loss,
        'reconstruction': reconstruction_loss,
        'attention': attention_loss,
        'total': total_loss
    }

# %%
def visualize_reconstructions(model, dataset):
    # Get multiple batches of images and select diverse samples
    sample_images = []
    for x_batch, _ in dataset.take(5):
        # Select 2 random images from each batch
        indices = tf.random.shuffle(tf.range(x_batch.shape[0]))[:2]
        sample_images.extend(tf.gather(x_batch, indices))
        if len(sample_images) >= 10:
            break
    
    sample_images = tf.stack(sample_images[:10])
    sample_images = tf.reshape(sample_images, [-1, 28, 28, 1])  # Ensure 4D shape
    
    # Reconstruct images
    _, reconstructed, _, _, _ = model(sample_images)
    
    # Plot results
    fig, axes = plt.subplots(2, 10, figsize=(20, 4))
    plt.suptitle('Original Images (top) vs Reconstructed Images (bottom)', y=1.05)
    
    for i in range(10):
        # Ensure proper shape for visualization
        orig_img = tf.squeeze(sample_images[i]).numpy()
        recon_img = tf.squeeze(reconstructed[i]).numpy()
        
        axes[0, i].imshow(orig_img, cmap='gray')
        axes[0, i].axis('off')
        axes[1, i].imshow(recon_img, cmap='gray')
        axes[1, i].axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
def train_model(model, train_dataset, valid_dataset, test_dataset, epochs=1500, 
                learning_rate=0.002, batch_size=250, log_dir="logs"):
    
    optimizer = tf.keras.optimizers.Adam(learning_rate)
    lambda_params = {'class': 20, 'ae': 1, 'attention': 0.1}
    
    for epoch in range(epochs):
        print(f"Epoch {epoch+1}/{epochs} ")
        
        # Training loop
        for x_batch, y_batch in train_dataset:
            # Apply elastic transform
            x_batch = tf.reshape(x_batch, [-1, 28, 28, 1])
            x_flat = tf.reshape(x_batch, [-1, 784])
            x_batch_elastic = batch_elastic_transform(x_flat, sigma=4, alpha=20, 
                                                    height=28, width=28)
            losses = train_step(model, optimizer, x_batch_elastic, y_batch, lambda_params)
            
        # Validation
        val_accuracy = tf.keras.metrics.CategoricalAccuracy()
        for x_val, y_val in valid_dataset:
            logits, _, _, _, _ = model(x_val)
            val_accuracy.update_state(y_val, logits)
            
        print(f"Validation accuracy: {val_accuracy.result():.4f}, Loss: {losses}\n")

# %%
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
# Create datasets
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(250)
valid_dataset = tf.data.Dataset.from_tensor_slices((x_test[:5000], y_test[:5000])).batch(250)
test_dataset = tf.data.Dataset.from_tensor_slices((x_test[5000:], y_test[5000:])).batch(250)

# %%
# Create and train model
model = AttentionAutoencoder(input_shape=(28, 28, 1), n_classes=10)
# Out:
# /u/prebello/dls/lib/python3.10/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 14, 14, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 7, 7, 32)       │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 4, 4, 32)       │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 4, 4, 10)       │         2,890 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 160)            │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,706 (84.79 KB)
#  Trainable params: 21,706 (84.79 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 160)            │         2,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 4, 4, 10)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 6, 6, 32)       │         2,912 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 12, 12, 32)     │         9,248 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 14, 14, 32)     │         9,248 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 28, 28, 1)      │           289 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,257 (94.75 KB)
#  Trainable params: 24,257 (94.75 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
train_model(model, train_dataset, valid_dataset, test_dataset)
# Out:
# Epoch 1/1500
# /u/prebello/dls/lib/python3.10/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (250, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# I0000 00:00:1733620006.649777 2284335 cuda_dnn.cc:529] Loaded cuDNN version 90400
# 2024-12-07 20:07:21.797016: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-12-07 20:07:22.113412: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation accuracy: 0.9494, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.21143008768558502>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.20915615558624268>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=4.437757968902588>}
#
# Epoch 2/1500
# 2024-12-07 20:07:55.064184: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation accuracy: 0.9630, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.16316907107830048>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.19456616044044495>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=3.4579477310180664>}
#
# Epoch 3/1500
# Validation accuracy: 0.9744, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.19960296154022217>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.18609388172626495>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=4.178153038024902>}
#
# Epoch 4/1500
# 2024-12-07 20:09:01.684367: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation accuracy: 0.9746, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.1404392123222351>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1827733963727951>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.9915575981140137>}
#
# Epoch 5/1500
# Validation accuracy: 0.9810, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.118929922580719>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.183968648314476>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.5625669956207275>}
#
# Epoch 6/1500
# Validation accuracy: 0.9810, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.11802062392234802>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1825634092092514>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.542975902557373>}
#
# Epoch 7/1500
# Validation accuracy: 0.9808, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08685888350009918>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.18123142421245575>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.918408989906311>}
#
# Epoch 8/1500
# 2024-12-07 20:11:15.038208: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation accuracy: 0.9828, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.13108722865581512>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.18268096446990967>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.8044257164001465>}
#
# Epoch 9/1500
# Validation accuracy: 0.9836, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09326973557472229>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17745298147201538>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.0428476333618164>}
#
# Epoch 10/1500
# Validation accuracy: 0.9856, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.11529780179262161>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17768925428390503>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.483645439147949>}
#
# Epoch 11/1500
# Validation accuracy: 0.9842, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.11758319288492203>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1777200847864151>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.529383897781372>}
#
# Epoch 12/1500
# Validation accuracy: 0.9838, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.1583135575056076>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1776200234889984>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=3.343891143798828>}
#
# Epoch 13/1500
# Validation accuracy: 0.9862, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09735091030597687>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17673346400260925>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.123751640319824>}
#
# Epoch 14/1500
# Validation accuracy: 0.9854, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.11006254702806473>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17439508438110352>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.3756461143493652>}
#
# Epoch 15/1500
# Validation accuracy: 0.9842, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08139213919639587>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1732081025838852>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.8010509014129639>}
#
# Epoch 16/1500
# 2024-12-07 20:15:41.657560: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation accuracy: 0.9868, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07431590557098389>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17553044855594635>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.661848545074463>}
#
# Epoch 17/1500
# Validation accuracy: 0.9862, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09839074313640594>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17275547981262207>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.1405704021453857>}
#
# Epoch 18/1500
# Validation accuracy: 0.9856, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10918983817100525>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17355582118034363>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.3573527336120605>}
#
# Epoch 19/1500
# Validation accuracy: 0.9862, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.11829119920730591>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1718839854001999>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.537708044052124>}
#
# Epoch 20/1500
# Validation accuracy: 0.9878, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07966017723083496>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.173227459192276>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.7664309740066528>}
#
# Epoch 21/1500
# Validation accuracy: 0.9856, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09865041077136993>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17485958337783813>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.1478676795959473>}
#
# Epoch 22/1500
# Validation accuracy: 0.9868, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07161124050617218>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17402952909469604>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.6062543392181396>}
#
# Epoch 23/1500
# Validation accuracy: 0.9888, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10802506655454636>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1712922900915146>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.3317935466766357>}
#
# Epoch 24/1500
# Validation accuracy: 0.9894, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06999474763870239>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17119210958480835>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.571087121963501>}
#
# Epoch 25/1500
# Validation accuracy: 0.9868, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08565860241651535>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16927431523799896>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.8824464082717896>}
#
# Epoch 26/1500
# Validation accuracy: 0.9852, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09087299555540085>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17115549743175507>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.9886153936386108>}
#
# Epoch 27/1500
# Validation accuracy: 0.9868, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10717198997735977>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17049165070056915>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.313931465148926>}
#
# Epoch 28/1500
# Validation accuracy: 0.9880, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06895428895950317>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17080187797546387>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.5498876571655273>}
#
# Epoch 29/1500
# Validation accuracy: 0.9856, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0819113701581955>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1689346879720688>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.8071621656417847>}
#
# Epoch 30/1500
# Validation accuracy: 0.9894, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10317575186491013>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16889318823814392>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.232408046722412>}
#
# Epoch 31/1500
# Validation accuracy: 0.9900, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08363715559244156>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17219069600105286>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.8449337482452393>}
#
# Epoch 32/1500
# 2024-12-07 20:24:33.175817: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation accuracy: 0.9914, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08710871636867523>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17406989634037018>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.9162442684173584>}
#
# Epoch 33/1500
# Validation accuracy: 0.9870, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0710301622748375>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17129793763160706>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.591901183128357>}
#
# Epoch 34/1500
# Validation accuracy: 0.9882, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07297717779874802>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17039431631565094>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.6299378871917725>}
#
# Epoch 35/1500
# Validation accuracy: 0.9894, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06684936583042145>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.169545978307724>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.5065332651138306>}
#
# Epoch 36/1500
# Validation accuracy: 0.9878, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10571771115064621>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17070308327674866>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.285057306289673>}
#
# Epoch 37/1500
# Validation accuracy: 0.9896, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.050589460879564285>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17453116178512573>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.1863203048706055>}
#
# Epoch 38/1500
# Validation accuracy: 0.9898, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07262875139713287>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17204435169696808>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.6246193647384644>}
#
# Epoch 39/1500
# Validation accuracy: 0.9886, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.11418679356575012>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17015306651592255>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.4538888931274414>}
#
# Epoch 40/1500
# Validation accuracy: 0.9900, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0943135991692543>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1718713343143463>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.058143377304077>}
#
# Epoch 41/1500
# Validation accuracy: 0.9896, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09082859009504318>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17009909451007843>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.986670970916748>}
#
# Epoch 42/1500
# Validation accuracy: 0.9876, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09029723703861237>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17087596654891968>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.976820707321167>}
#
# Epoch 43/1500
# Validation accuracy: 0.9890, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05951305851340294>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1693296879529953>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.359590768814087>}
#
# Epoch 44/1500
# Validation accuracy: 0.9890, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06333151459693909>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17133891582489014>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.4379692077636719>}
#
# Epoch 45/1500
# Validation accuracy: 0.9904, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.062340810894966125>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16889263689517975>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.4157087802886963>}
#
# Epoch 46/1500
# Validation accuracy: 0.9898, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06216902658343315>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16833269596099854>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.4117132425308228>}
#
# Epoch 47/1500
# Validation accuracy: 0.9890, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08110951632261276>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16641268134117126>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.7886030673980713>}
#
# Epoch 48/1500
# Validation accuracy: 0.9900, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04398408159613609>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.168661966919899>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.0483436584472656>}
#
# Epoch 49/1500
# Validation accuracy: 0.9868, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0694088414311409>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.17015111446380615>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.5583279132843018>}
#
# Epoch 50/1500
# Validation accuracy: 0.9892, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06248306483030319>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16713161766529083>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.4167929887771606>}
#
# Epoch 51/1500
# Validation accuracy: 0.9906, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06553971022367477>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16782595217227936>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.478620171546936>}
#
# Epoch 52/1500
# Validation accuracy: 0.9882, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06285923719406128>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16802608966827393>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.4252108335494995>}
#
# Epoch 53/1500
# Validation accuracy: 0.9900, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.049449723213911057>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16644352674484253>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.15543794631958>}
#
# Epoch 54/1500
# Validation accuracy: 0.9886, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.058692026883363724>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16812551021575928>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.3419660329818726>}
#
# Epoch 55/1500
# Validation accuracy: 0.9900, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06825654208660126>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16725696623325348>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.5323878526687622>}
#
# Epoch 56/1500
# Validation accuracy: 0.9880, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05565546080470085>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1671907603740692>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.2803000211715698>}
#
# Epoch 57/1500
# Validation accuracy: 0.9904, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05995162948966026>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16530673205852509>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.3643392324447632>}
#
# Epoch 58/1500
# Validation accuracy: 0.9916, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10562824457883835>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1653534173965454>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=2.2779183387756348>}
#
# Epoch 59/1500
# Validation accuracy: 0.9910, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05884562432765961>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16388528048992157>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.340797781944275>}
#
# Epoch 60/1500
# Validation accuracy: 0.9874, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08149208128452301>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1686873883008957>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.7985289096832275>}
#
# Epoch 61/1500
# Validation accuracy: 0.9894, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07290593534708023>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16950242221355438>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.627621054649353>}
#
# Epoch 62/1500
# Validation accuracy: 0.9904, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05611573904752731>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1678592413663864>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.2901740074157715>}
#
# Epoch 63/1500
# Validation accuracy: 0.9888, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07933550328016281>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16475342214107513>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.751463532447815>}
#
# Epoch 64/1500
# 2024-12-07 20:42:12.377965: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation accuracy: 0.9886, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08070772886276245>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1687857210636139>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.7829402685165405>}
#
# Epoch 65/1500
# Validation accuracy: 0.9906, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.057919230312108994>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16404277086257935>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.3224272727966309>}
#
# Epoch 66/1500
# Validation accuracy: 0.9882, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07583405822515488>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16911087930202484>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.685792088508606>}
#
# Epoch 67/1500
# Validation accuracy: 0.9894, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06046103686094284>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16514483094215393>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.3743655681610107>}
#
# Epoch 68/1500
# Validation accuracy: 0.9906, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05444294214248657>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16545657813549042>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.2543153762817383>}
#
# Epoch 69/1500
# Validation accuracy: 0.9890, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06771212071180344>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16849637031555176>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.5227388143539429>}
#
# Epoch 70/1500
# Validation accuracy: 0.9890, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06791658699512482>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16680710017681122>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.5251387357711792>}
#
# Epoch 71/1500
# Validation accuracy: 0.9896, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.058619432151317596>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16495467722415924>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.3373433351516724>}
#
# Epoch 72/1500
# Validation accuracy: 0.9892, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06806759536266327>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16601672768592834>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.5273686647415161>}
#
# Epoch 73/1500
# Validation accuracy: 0.9890, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04664884880185127>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16504105925559998>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.0980180501937866>}
#
# Epoch 74/1500
# Validation accuracy: 0.9878, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07637674361467361>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16465122997760773>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.6921861171722412>}
#
# Epoch 75/1500
# Validation accuracy: 0.9904, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05565406382083893>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16498492658138275>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.2780661582946777>}
#
# Epoch 76/1500
# Validation accuracy: 0.9890, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04400694742798805>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1655777543783188>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.045716643333435>}
#
# Epoch 77/1500
# Validation accuracy: 0.9890, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06575612723827362>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1627005636692047>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.4778231382369995>}
#
# Epoch 78/1500
# Validation accuracy: 0.9896, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05662284046411514>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16540418565273285>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.2978609800338745>}
#
# Epoch 79/1500
# Validation accuracy: 0.9906, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04644182696938515>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16588272154331207>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.0947192907333374>}
#
# Epoch 80/1500
# Validation accuracy: 0.9904, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04859991371631622>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1663052886724472>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.138303518295288>}
#
# Epoch 81/1500
# Validation accuracy: 0.9898, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.051760029047727585>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16845276951789856>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.203653335571289>}
#
# Epoch 82/1500
# Validation accuracy: 0.9906, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.048621609807014465>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16447997093200684>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.1369121074676514>}
#
# Epoch 83/1500
# Validation accuracy: 0.9918, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.055602412670850754>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1667981743812561>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.2788465023040771>}
#
# Epoch 84/1500
# Validation accuracy: 0.9908, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.054093293845653534>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16519863903522491>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.2470645904541016>}
#
# Epoch 85/1500
# Validation accuracy: 0.9918, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05322589352726936>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16350574791431427>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.228023648262024>}
#
# Epoch 86/1500
# Validation accuracy: 0.9886, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04557562619447708>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16427482664585114>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.0757873058319092>}
#
# Epoch 87/1500
# Validation accuracy: 0.9916, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04669608548283577>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16232679784297943>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.0962485074996948>}
#
# Epoch 88/1500
# Validation accuracy: 0.9884, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05687161535024643>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16213597357273102>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.2995682954788208>}
#
# Epoch 89/1500
# Validation accuracy: 0.9888, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06150636076927185>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16339269280433655>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.3935198783874512>}
#
# Epoch 90/1500
# Validation accuracy: 0.9906, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05355660244822502>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16499707102775574>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.2361291646957397>}
#
# Epoch 91/1500
# Validation accuracy: 0.9894, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04783923923969269>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1619316190481186>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.1187163591384888>}
#
# Epoch 92/1500
# Validation accuracy: 0.9898, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04032643884420395>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16518431901931763>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.971713125705719>}
#
# Epoch 93/1500
# Validation accuracy: 0.9904, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08694899827241898>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16388040781021118>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.902860403060913>}
#
# Epoch 94/1500
# Validation accuracy: 0.9894, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0369500070810318>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16485394537448883>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.9038540720939636>}
#
# Epoch 95/1500
# Validation accuracy: 0.9882, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04589694365859032>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1652149260044098>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.0831538438796997>}
#
# Epoch 96/1500
# Validation accuracy: 0.9902, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.049300387501716614>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16320477426052094>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.1492124795913696>}
#
# Epoch 97/1500
# Validation accuracy: 0.9910, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05472923815250397>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16395199298858643>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.258536696434021>}
#
# Epoch 98/1500
# Validation accuracy: 0.9912, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05103728175163269>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16156698763370514>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.1823126077651978>}
#
# Epoch 99/1500
# Validation accuracy: 0.9888, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07046380639076233>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16140349209308624>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.5706796646118164>}
#
# Epoch 100/1500
# Validation accuracy: 0.9898, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04862259328365326>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16517889499664307>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.1376307010650635>}
#
# Epoch 101/1500
# Validation accuracy: 0.9882, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04795840010046959>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16316762566566467>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.12233567237854>}
#
# Epoch 102/1500
# Validation accuracy: 0.9908, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05429217964410782>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16272814571857452>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.248571753501892>}
#
# Epoch 103/1500
# Validation accuracy: 0.9908, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.053120724856853485>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16267549991607666>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.2250900268554688>}
#
# Epoch 104/1500
# Validation accuracy: 0.9898, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04891485720872879>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1648786962032318>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.1431758403778076>}
#
# Epoch 105/1500
# Validation accuracy: 0.9916, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05807113274931908>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16210611164569855>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.32352876663208>}
#
# Epoch 106/1500
# Validation accuracy: 0.9906, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05886312201619148>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1615968644618988>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.3388593196868896>}
#
# Epoch 107/1500
# Validation accuracy: 0.9902, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04440951719880104>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16458800435066223>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.0527783632278442>}
#
# Epoch 108/1500
# Validation accuracy: 0.9910, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04505429416894913>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16352154314517975>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.0646073818206787>}
#
# Epoch 109/1500
# Validation accuracy: 0.9912, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.045686446130275726>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16080912947654724>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.0745381116867065>}
#
# Epoch 110/1500
# Validation accuracy: 0.9896, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07309531420469284>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1616578847169876>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.6235642433166504>}
#
# Epoch 111/1500
# Validation accuracy: 0.9904, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0740576684474945>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16143174469470978>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.6425851583480835>}
#
# Epoch 112/1500
# Validation accuracy: 0.9896, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.044803205877542496>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16304364800453186>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.059107780456543>}
#
# Epoch 113/1500
# Validation accuracy: 0.9898, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06262964755296707>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16268962621688843>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.4152824878692627>}
#
# Epoch 114/1500
# Validation accuracy: 0.9898, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05285997316241264>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16210155189037323>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.2193009853363037>}
#
# Epoch 115/1500
# Validation accuracy: 0.9918, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05852176621556282>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16172461211681366>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.3321598768234253>}
#
# Epoch 116/1500
# Validation accuracy: 0.9930, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.043038126081228256>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16241444647312164>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.0231770277023315>}
#
# Epoch 117/1500
# Validation accuracy: 0.9908, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06192335486412048>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16184182465076447>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.4003089666366577>}
#
# Epoch 118/1500
# Validation accuracy: 0.9910, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05252024531364441>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1628704071044922>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.2132753133773804>}
#
# Epoch 119/1500
# Validation accuracy: 0.9886, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06846697628498077>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16219282150268555>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.5315322875976562>}
#
# Epoch 120/1500
# Validation accuracy: 0.9916, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04597236588597298>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1598609834909439>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.079308271408081>}
#
# Epoch 121/1500
# Validation accuracy: 0.9910, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04451455920934677>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16196002066135406>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.0522512197494507>}
#
# Epoch 122/1500
# Validation accuracy: 0.9914, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07152267545461655>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16241228580474854>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.5928658246994019>}
#
# Epoch 123/1500
# Validation accuracy: 0.9900, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.05918755754828453>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1592935174703598>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.343044638633728>}
#
# Epoch 124/1500
# Validation accuracy: 0.9898, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.03636368364095688>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16085553169250488>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.8881292343139648>}
#
# Epoch 125/1500
# Validation accuracy: 0.9892, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.051814258098602295>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1594223976135254>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.1957075595855713>}
#
# Epoch 126/1500
# Validation accuracy: 0.9900, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.029428530484437943>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16342701017856598>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.7519975900650024>}
#
# Epoch 127/1500
# Validation accuracy: 0.9898, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.049079108983278275>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1616455614566803>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.1432276964187622>}
#
# Epoch 128/1500
# 2024-12-07 21:18:15.357404: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation accuracy: 0.9898, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08908432722091675>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16056488454341888>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.942251443862915>}
#
# Epoch 129/1500
# Validation accuracy: 0.9910, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07799661159515381>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16069161891937256>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.7206238508224487>}
#
# Epoch 130/1500
# Validation accuracy: 0.9892, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.03368454799056053>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16306374967098236>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.8367547392845154>}
#
# Epoch 131/1500
# Validation accuracy: 0.9892, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.03829489275813103>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16167593002319336>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.9275738000869751>}
#
# Epoch 132/1500
# ...
#
# Epoch 1456/1500
# Validation accuracy: 0.9914, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0068795219995081425>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1606469601392746>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.2982373833656311>}
#
# Epoch 1457/1500
# Validation accuracy: 0.9908, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.030725175514817238>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16133688390254974>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.7758404016494751>}
#
# Epoch 1458/1500
# Validation accuracy: 0.9914, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.03008679673075676>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1615980714559555>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.7633340358734131>}
#
# Epoch 1459/1500
# Validation accuracy: 0.9906, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.02992549166083336>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15936845541000366>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.757878303527832>}
#
# Epoch 1460/1500
# Validation accuracy: 0.9914, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.012211299501359463>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16014760732650757>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.4043735861778259>}
#
# Epoch 1461/1500
# Validation accuracy: 0.9918, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.03374418243765831>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16097021102905273>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.8358538746833801>}
#
# Epoch 1462/1500
# Validation accuracy: 0.9896, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.03256149962544441>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16076761484146118>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.8119975924491882>}
#
# Epoch 1463/1500
# Validation accuracy: 0.9916, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04485117271542549>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16075101494789124>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.0577744245529175>}
#
# Epoch 1464/1500
# Validation accuracy: 0.9926, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.014709237031638622>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1619025468826294>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.45608729124069214>}
#
# Epoch 1465/1500
# Validation accuracy: 0.9916, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.008530911058187485>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15921124815940857>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.32982945442199707>}
#
# Epoch 1466/1500
# Validation accuracy: 0.9918, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.014469326473772526>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15965396165847778>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.4490405023097992>}
#
# Epoch 1467/1500
# Validation accuracy: 0.9926, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.03770765662193298>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15885180234909058>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.9130049347877502>}
#
# Epoch 1468/1500
# Validation accuracy: 0.9908, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0314805693924427>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1580057591199875>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.7876171469688416>}
#
# Epoch 1469/1500
# Validation accuracy: 0.9918, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.020634956657886505>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15923380851745605>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.5719329118728638>}
#
# Epoch 1470/1500
# Validation accuracy: 0.9928, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0038440057542175055>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1621514856815338>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.2390315979719162>}
#
# Epoch 1471/1500
# Validation accuracy: 0.9904, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.03031899780035019>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16156481206417084>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.7679448127746582>}
#
# Epoch 1472/1500
# Validation accuracy: 0.9910, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.009225151501595974>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16172297298908234>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.3462260067462921>}
#
# Epoch 1473/1500
# Validation accuracy: 0.9898, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04183417186141014>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15937988460063934>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.9960633516311646>}
#
# Epoch 1474/1500
# Validation accuracy: 0.9914, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.03601907938718796>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16235439479351044>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.8827360272407532>}
#
# Epoch 1475/1500
# Validation accuracy: 0.9914, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.015411662869155407>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16203337907791138>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.4702666401863098>}
#
# Epoch 1476/1500
# Validation accuracy: 0.9908, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.016622355207800865>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16300013661384583>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.4954472482204437>}
#
# Epoch 1477/1500
# Validation accuracy: 0.9924, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06615518778562546>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16100114583969116>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.484104871749878>}
#
# Epoch 1478/1500
# Validation accuracy: 0.9910, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.022541163489222527>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1614888310432434>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.6123120784759521>}
#
# Epoch 1479/1500
# Validation accuracy: 0.9912, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.005284124054014683>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16058026254177094>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.2662627398967743>}
#
# Epoch 1480/1500
# Validation accuracy: 0.9922, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.020247604697942734>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16068781912326813>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.5656399130821228>}
#
# Epoch 1481/1500
# Validation accuracy: 0.9898, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.02234550006687641>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15848049521446228>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.6053904891014099>}
#
# Epoch 1482/1500
# Validation accuracy: 0.9920, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.02122923731803894>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16106024384498596>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.5856449604034424>}
#
# Epoch 1483/1500
# Validation accuracy: 0.9920, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.017228249460458755>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.161069855093956>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.5056348443031311>}
#
# Epoch 1484/1500
# Validation accuracy: 0.9910, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.044891227036714554>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16256073117256165>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.0603852272033691>}
#
# Epoch 1485/1500
# Validation accuracy: 0.9914, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.013561971485614777>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1604567915201187>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.43169623613357544>}
#
# Epoch 1486/1500
# Validation accuracy: 0.9910, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0431397520005703>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16079089045524597>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.0235859155654907>}
#
# Epoch 1487/1500
# Validation accuracy: 0.9916, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04760010167956352>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16196994483470917>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.1139719486236572>}
#
# Epoch 1488/1500
# Validation accuracy: 0.9932, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.019030170515179634>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16137352585792542>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.5419769287109375>}
#
# Epoch 1489/1500
# Validation accuracy: 0.9924, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.03229735791683197>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16073891520500183>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.8066860437393188>}
#
# Epoch 1490/1500
# Validation accuracy: 0.9926, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.01219928078353405>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16341981291770935>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.40740543603897095>}
#
# Epoch 1491/1500
# Validation accuracy: 0.9922, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.03488096222281456>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1623871922492981>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.8600064516067505>}
#
# Epoch 1492/1500
# Validation accuracy: 0.9920, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.015554245561361313>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16020610928535461>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.47129103541374207>}
#
# Epoch 1493/1500
# Validation accuracy: 0.9932, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04316551983356476>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16202782094478607>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.0253381729125977>}
#
# Epoch 1494/1500
# Validation accuracy: 0.9938, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.012363497167825699>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16434544324874878>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.41161537170410156>}
#
# Epoch 1495/1500
# Validation accuracy: 0.9924, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0159129798412323>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15946298837661743>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.4777225852012634>}
#
# Epoch 1496/1500
# Validation accuracy: 0.9932, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.04806898534297943>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16210836172103882>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=1.1234880685806274>}
#
# Epoch 1497/1500
# Validation accuracy: 0.9928, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.01003840658813715>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.162133127450943>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.3629012703895569>}
#
# Epoch 1498/1500
# Validation accuracy: 0.9916, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.02480757050216198>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16157029569149017>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.6577216982841492>}
#
# Epoch 1499/1500
# Validation accuracy: 0.9910, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.030659053474664688>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16002577543258667>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.7732068300247192>}
#
# Epoch 1500/1500
# Validation accuracy: 0.9922, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.02820868417620659>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16075533628463745>, 'attention': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=0.7249290347099304>}

# %%
model.save("mnist_attention_model.keras")

# %%
model_save = tf.keras.models.load_model("mnist_attention_model.keras", custom_objects={"AttentionAutoencoder": AttentionAutoencoder})
# Out:
# /u/prebello/dls/lib/python3.10/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 14, 14, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 7, 7, 32)       │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 4, 4, 32)       │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 4, 4, 10)       │         2,890 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 160)            │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,706 (84.79 KB)
#  Trainable params: 21,706 (84.79 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 160)            │         2,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 4, 4, 10)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 6, 6, 32)       │         2,912 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 12, 12, 32)     │         9,248 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_6              │ (None, 14, 14, 32)     │         9,248 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_7              │ (None, 28, 28, 1)      │           289 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,257 (94.75 KB)
#  Trainable params: 24,257 (94.75 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# /u/prebello/dls/lib/python3.10/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (250, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(

# %%
visualize_reconstructions(model, train_dataset)
# Out:
# /u/prebello/dls/lib/python3.10/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (10, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(

# %%
def visualize_image_class_weights(model, dataset):
    # Get one sample image from each class
    images_by_class = [[] for _ in range(10)]
    for x_batch, y_batch in dataset:
        y_labels = tf.argmax(y_batch, axis=1)
        for img, label in zip(x_batch, y_labels):
            images_by_class[label.numpy()].append(img)
        if all(len(c) > 0 for c in images_by_class):
            break
    
    # Select first image from each class
    sample_images = [class_images[0] for class_images in images_by_class]
    sample_images = tf.stack(sample_images)
    
    # Get logits through the model
    logits, _, _, _, _ = model(sample_images)
    
    # Create figure with proper sizing
    fig = plt.figure(figsize=(15, 10))
    gs = plt.GridSpec(2, 1, height_ratios=[4, 1])
    
    # Plot weight matrix
    ax_weights = fig.add_subplot(gs[0])
    im = ax_weights.imshow(logits.numpy(), cmap='RdBu_r')
    plt.colorbar(im)
    
    # Add weight values in cells
    for i in range(logits.shape[0]):
        for j in range(logits.shape[1]):
            text_color = 'white' if abs(logits[i, j]) > 10 else 'black'
            ax_weights.text(j, i, f'{logits[i, j]:.2f}',
                          ha='center', va='center', color=text_color)
    
    # Plot sample digits on right side
    ax_images = fig.add_subplot(gs[1])
    for i in range(10):
        ax_images.imshow(sample_images[i], 
                        extent=[i-0.5, i+0.5, 0, 1],
                        cmap='gray')
    
    # Configure axes
    ax_weights.set_xticks(range(10))
    ax_weights.set_xticklabels(range(10))
    ax_weights.set_ylabel('Input Images')
    ax_weights.set_xlabel('Digit Classes')
    ax_images.set_xticks([])
    ax_images.set_yticks([])
    
    plt.suptitle('Image-to-Class Weight Matrix')
    plt.tight_layout()
    plt.show()

# %%
visualize_image_class_weights(model, train_dataset)

# %%
val_accuracy = tf.keras.metrics.CategoricalAccuracy()
for x_tst, y_tst in test_dataset:
    logits, decoded_images, features, attended_features, attention_weights = model(x_tst)
    val_accuracy.update_state(y_tst, logits)
    
print(f"Test accuracy: {val_accuracy.result():.4f}\n")
# Out:
# /u/prebello/dls/lib/python3.10/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (250, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# Test accuracy: 0.9944

# %%
batch_size = 10
inputs = x_test[:batch_size]  

logits, decoded_images, features, attended_features, attention_weights = model(inputs)
activations = attended_features.numpy() 
reconstructed_images = decoded_images.numpy()
attention_weights = attention_weights.numpy()

# %%
# Plot original images, reconstructed images, and prototypes
fig, axes = plt.subplots(3, batch_size, figsize=(15, 6))

for i in range(batch_size):
    # Original image
    axes[0, i].imshow(inputs[i].reshape(28, 28), cmap='gray')
    axes[0, i].axis('off')
    axes[0, i].set_title("Original")

    # Reconstructed image
    axes[1, i].imshow(reconstructed_images[i].reshape(28, 28), cmap='gray')
    axes[1, i].axis('off')
    axes[1, i].set_title("Reconstructed")

    # Prototype as heatmap
    activation = activations[i]
    axes[2, i].imshow(activation.reshape(1, -1), cmap='hot', aspect='auto')  # Reshape for heatmap
    axes[2, i].axis('off')
    axes[2, i].set_title("Activations")

plt.tight_layout()
plt.show()

# %%
# Check the shape of attention_weights
print("Attention Weights Shape:", attention_weights.shape)
# Out:
# Attention Weights Shape: (10, 1, 1)

# %%
import numpy as np

def compute_attention_rollout(attention_weights, image_size=28):
    print("Attention weights shape:", attention_weights.shape)
    attention = tf.squeeze(attention_weights)  # Shape becomes (10,)
    attention = tf.reshape(attention, (-1, 1)) @ tf.reshape(attention, (1, -1))
    attention = attention + tf.eye(10)
    attention = attention / tf.reduce_sum(attention, axis=-1, keepdims=True)
    rollout = tf.eye(10)
    rollout = tf.matmul(rollout, attention)
    rollout = (rollout - tf.reduce_min(rollout)) / (tf.reduce_max(rollout) - tf.reduce_min(rollout))
    rollout = tf.reshape(rollout, (10, 10, 1))
    rollout = tf.image.resize(rollout, (image_size, image_size), method='bicubic')
    return rollout

def process_attention_map(rollout, image_size=28):
    attention_map = tf.reshape(rollout, [-1, int(tf.sqrt(float(rollout.shape[-1]))), 
                                       int(tf.sqrt(float(rollout.shape[-1])))])
    attention_map = tf.image.resize(attention_map, [image_size, image_size])
    attention_map = tf.image.resize(attention_map, [image_size, image_size], 
                                  method='gaussian')
    return attention_map

# Visualize attention rollout
def create_attention_visualization(attention_map, original_image=None):
    attention_map = tf.cast(attention_map, tf.float32)
    
    # Create heatmap
    heatmap = tf.image.resize(attention_map, [28, 28])
    heatmap = tf.image.grayscale_to_rgb(heatmap)
    
    if original_image is not None:
        original_image = tf.cast(original_image, tf.float32)
        if len(original_image.shape) == 2:
            original_image = tf.stack([original_image] * 3, axis=-1)
            
        original_image = original_image / tf.reduce_max(original_image)
        heatmap = heatmap / tf.reduce_max(heatmap)
        
        alpha = 0.6
        overlay = alpha * original_image + (1 - alpha) * heatmap
        return overlay
    return heatmap

# %%
from tensorflow.keras.models import load_model

model = load_model('mnist_attention_model.keras', custom_objects={'AttentionAutoencoder': AttentionAutoencoder})
# Out:
# /u/prebello/dls/lib/python3.10/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 14, 14, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 7, 7, 32)       │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 4, 4, 32)       │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 4, 4, 10)       │         2,890 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 160)            │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,706 (84.79 KB)
#  Trainable params: 21,706 (84.79 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 160)            │         2,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 4, 4, 10)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 6, 6, 32)       │         2,912 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 12, 12, 32)     │         9,248 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_6              │ (None, 14, 14, 32)     │         9,248 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_7              │ (None, 28, 28, 1)      │           289 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,257 (94.75 KB)
#  Trainable params: 24,257 (94.75 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# /u/prebello/dls/lib/python3.10/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (250, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(

# %%
test_image = x_test[0]
test_image = tf.expand_dims(test_image, 0)
logits, decoded_images, features, attended_features, attention_weights = model(test_image)

# Get attention rollout
rollout = compute_attention_rollout(attention_weights)

# Process attention map
attention_map = process_attention_map(rollout)

heatmap = create_attention_visualization(attention_map, x_test[0])
# Out:
# Attention weights shape: (1, 1, 1)

# %%
def plot_attention_visualization(original_image, attention_map):
    plt.figure(figsize=(12, 5))
    
    # Plot original image
    plt.subplot(1, 2, 1)
    plt.title('Original Image')
    plt.imshow(original_image, cmap='viridis')
    plt.axis('off')
    
    # Plot attention map
    plt.subplot(1, 2, 2)
    plt.title('Attention Map')
    im = plt.imshow(heatmap, cmap='viridis', vmin=-0.100, vmax=0.100)
    plt.colorbar(im, orientation='vertical')
    plt.axis('off')
    
    plt.tight_layout()
    plt.show()
plot_attention_visualization(tf.squeeze(test_image), tf.squeeze(heatmap))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.042531848..0.99764705].

# %%
def visualize_image_attention_features_flipped(model, dataset):
    # Get one sample image from each class
    images_by_class = [[] for _ in range(10)]
    for x_batch, y_batch in dataset:
        y_labels = tf.argmax(y_batch, axis=1)
        for img, label in zip(x_batch, y_labels):
            images_by_class[label.numpy()].append(img)
        if all(len(c) > 0 for c in images_by_class):
            break
    
    # Select first image from each class
    sample_images = [class_images[0] for class_images in images_by_class]
    sample_images = tf.stack(sample_images)
    
    # Get features through the model
    logits, decoded_images, features, attention_features, attention_weights = model(sample_images)
    
    # Convert attention features to numpy and transpose for flipped axes
    attention_features = attention_features.numpy().T  # Transpose matrix
    
    # Create figure
    fig, ax = plt.subplots(figsize=(10, 8))
    cax = ax.matshow(attention_features, cmap='RdBu_r')
    fig.colorbar(cax)

    # Annotate cells with feature values
    for i in range(attention_features.shape[0]):
        for j in range(attention_features.shape[1]):
            text_color = 'white' if attention_features[i, j] > 0.5 * attention_features.max() else 'black'
            ax.text(j, i, f'{attention_features[i, j]:.2f}', ha='center', va='center', color=text_color)
    
    # Configure axes
    ax.set_xticks(range(10))
    ax.set_xticklabels(range(10))
    ax.set_yticks(range(attention_features.shape[0]))
    ax.set_yticklabels([f"Feature {i+1}" for i in range(attention_features.shape[0])])
    ax.set_xlabel('Input Images (Digit Classes)')
    ax.set_ylabel('Attention Features')
    plt.title('Attention Feature-to-Image Mapping')
    plt.tight_layout()
    plt.show()

# Assuming `model` is an instance of AttentionAutoencoder and `dataset` is a batched tf.data.Dataset
visualize_image_attention_features_flipped(model, train_dataset)

# %%
def evaluate_classification_accuracy(model, test_dataset):
    """
    Evaluate classification accuracy of the model
    Args:
    - model: Trained AttentionAutoencoder model
    - test_dataset: Test dataset
    Returns:
    - Accuracy
    - Confusion Matrix
    """
    # Collect true labels and predicted labels
    true_labels = []
    predicted_labels = []

    # Iterate through the test dataset
    for batch in test_dataset:
        # Unpack images and labels
        images, labels = batch

        # Ensure images are in the right shape
        if len(images.shape) == 3:
            images = tf.expand_dims(images, axis=-1)

        # Get logits from the model
        logits, *_ = model(images)

        # Get predicted classes
        predictions = tf.argmax(logits, axis=1)

        # If labels are one-hot encoded, convert to class indices
        if len(labels.shape) > 1:
            labels = tf.argmax(labels, axis=1)

        # Extend the lists
        true_labels.extend(labels.numpy())
        predicted_labels.extend(predictions.numpy())

    # Convert to numpy arrays
    true_labels = np.array(true_labels)
    predicted_labels = np.array(predicted_labels)

    # Calculate accuracy
    accuracy = np.mean(true_labels == predicted_labels)

    # Compute confusion matrix
    confusion_matrix = tf.math.confusion_matrix(
        labels=true_labels,
        predictions=predicted_labels,
        num_classes=10  # MNIST has 10 classes
    ).numpy()

    return accuracy, confusion_matrix, true_labels, predicted_labels

# %%
import seaborn as sns
# Visualize confusion matrix
accuracy, conf_matrix, true_labels, predicted_labels = evaluate_classification_accuracy(model, test_dataset)
print(f"Classification Accuracy: {accuracy * 100:.2f}%")
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# /u/prebello/dls/lib/python3.10/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (250, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 2024-12-15 23:41:53.788838: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Classification Accuracy: 99.44%
