# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import map_coordinates
from scipy.ndimage import gaussian_filter
from tqdm import tqdm
import os
# Out:
# 2024-12-01 00:36:19.459889: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733031379.477709  518456 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733031379.482055  518456 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-01 00:36:19.500270: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load MNIST dataset
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
def batch_elastic_transform(images, sigma, alpha, height, width, random_state=None):
    """
    Elastic deformation of images as described in [Simard 2003].
    
    Args:
        images: a two-dimensional numpy array; list of flattened images
        sigma: variance of the gaussian kernel
        alpha: multiplier for the displacement fields
        height: image height
        width: image width
        random_state: numpy random state object
    
    Returns:
        elastically distorted images of the same shape
    """
    assert len(images.shape) == 2
    e_images = np.empty_like(images)
    e_images[:] = images
    
    e_images = e_images.reshape(-1, height, width)
    
    if random_state is None:
        random_state = np.random.RandomState(None)
    x, y = np.mgrid[0:height, 0:width]
    
    for i in range(e_images.shape[0]):
        dx = gaussian_filter((random_state.rand(height, width) * 2 - 1), 
                           sigma, mode='constant') * alpha
        dy = gaussian_filter((random_state.rand(height, width) * 2 - 1), 
                           sigma, mode='constant') * alpha
        indices = x + dx, y + dy
        e_images[i] = map_coordinates(e_images[i], indices, order=1)

    return e_images.reshape(-1, height*width)

# %%
random_state = np.random.RandomState(None)
dx1 = random_state.rand(28, 28) * 2 - 1
dy1 = random_state.rand(28, 28) * 2 - 1
dx2 = gaussian_filter(dx1, 4, mode='constant')
dy2 = gaussian_filter(dy1, 4, mode='constant')

# %%
x, y = np.mgrid[0:28, 0:28]
    
plt.figure(figsize=(12, 4))
plt.subplot(131)
plt.quiver(x, y, dx1, dy1)
plt.title('Before Gaussian Filter')
plt.subplot(132)
plt.quiver(x, y, dx2, dy2)
plt.title('After Gaussian Filter')
# Demonstrate elastic transform on MNIST image
img = x_train[0]
plt.subplot(133)
plt.imshow(img, cmap='gray')
plt.title('Original Image')
plt.show()

# %%
transformed_img = batch_elastic_transform(
    img.reshape(1, -1), 
    sigma=4, 
    alpha=20, 
    height=28, 
    width=28
)
    
plt.figure(figsize=(4, 4))
plt.imshow(transformed_img.reshape(28, 28), cmap='gray')
plt.title('Transformed Image')
plt.show()

# %%
def transform_dataset(x_train, batch_size=1000, sigma=4, alpha=20):
    """
    Transform entire dataset in batches to avoid memory issues
    """
    height, width = x_train.shape[1:]
    n_samples = x_train.shape[0]
    
    # Initialize array for transformed images
    transformed_images = np.zeros((n_samples, height * width))
    
    # Process in batches
    for i in tqdm(range(0, n_samples, batch_size)):
        batch_end = min(i + batch_size, n_samples)
        batch = x_train[i:batch_end]
        
        # Reshape batch to 2D array (n_samples, pixels)
        batch_flat = batch.reshape(batch_end - i, -1)
        
        # Apply transformation
        transformed = batch_elastic_transform(
            batch_flat, 
            sigma=sigma, 
            alpha=alpha,
            height=height,
            width=width
        )
        
        transformed_images[i:batch_end] = transformed
    
    return transformed_images

# %%
transformed_train = transform_dataset(x_train)
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]
# 100%|██████████| 60/60 [00:09<00:00,  6.27it/s]

# %%
def plot_comparison(original, transformed, num_images=5):
    plt.figure(figsize=(2*num_images, 4))
    
    for i in range(num_images):
        # Original image
        plt.subplot(2, num_images, i + 1)
        plt.imshow(original[i], cmap='gray')
        plt.axis('off')
        if i == 0:
            plt.title('Original')
            
        # Transformed image
        plt.subplot(2, num_images, num_images + i + 1)
        plt.imshow(transformed[i].reshape(28, 28), cmap='gray')
        plt.axis('off')
        if i == 0:
            plt.title('Transformed')
    
    plt.tight_layout()
    plt.show()

# Plot some examples
plot_comparison(x_train, transformed_train)

# %%
def list_of_norms(X):
    """
    Computes squared L2 norm for each vector in X.
    
    Args:
        X: tensor of shape [n, d] containing n d-dimensional vectors
    
    Returns:
        tensor of shape [n] containing squared L2 norms
    """
    return tf.reduce_sum(tf.pow(X, 2), axis=1)

# %%
def list_of_distances(X, Y):
    """
    Computes pairwise squared Euclidean distances between two sets of vectors.
    
    Args:
        X: tensor of shape [n, d] containing n d-dimensional vectors
        Y: tensor of shape [m, d] containing m d-dimensional vectors
    
    Returns:
        tensor of shape [n, m] containing all pairwise distances
    """
    XX = tf.reshape(list_of_norms(X), shape=(-1, 1))
    YY = tf.reshape(list_of_norms(Y), shape=(1, -1))
    output = XX + YY - 2 * tf.matmul(X, tf.transpose(Y))
    
    return output

# %%
class PrototypeAutoencoder(tf.keras.Model):
    def __init__(self, input_shape, n_classes, n_prototypes=15):
        super(PrototypeAutoencoder, self).__init__()
        # Network parameters
        self.n_prototypes = n_prototypes
        self.input_shape = input_shape
        self.n_classes = n_classes
        
        # Encoder layers
        self.encoder = tf.keras.Sequential([
            tf.keras.layers.InputLayer(input_shape=input_shape),
            tf.keras.layers.Conv2D(32, 3, strides=2, padding='same', activation='relu'),
            tf.keras.layers.Conv2D(32, 3, strides=2, padding='same', activation='relu'),
            tf.keras.layers.Conv2D(32, 3, strides=2, padding='same', activation='relu'),
            tf.keras.layers.Conv2D(10, 3, strides=1, padding='same', activation='relu'),
            tf.keras.layers.Flatten()
        ])
        
        # Decoder layers
        self.decoder = tf.keras.Sequential([
            tf.keras.layers.InputLayer(shape=(160,)),
            tf.keras.layers.Dense(4*4*10),
            tf.keras.layers.Reshape((4, 4, 10)),
            tf.keras.layers.Conv2DTranspose(32, 3, strides=1, padding='valid', activation='relu'),  # 4x4x32
            tf.keras.layers.Conv2DTranspose(32, 3, strides=2, padding='same', activation='relu'),  # 8x8x32
            tf.keras.layers.Conv2DTranspose(32, 3, strides=1, padding='valid', activation='relu'),  # 14x14x32
            tf.keras.layers.Conv2DTranspose(1, 3, strides=2, padding='same', activation='sigmoid') # 28x28x1
        ])
        
        # Prototype vectors
        self.prototype_vectors = tf.Variable(
            tf.random.uniform(shape=[n_prototypes, 4*4*10], dtype=tf.float32),
            name='prototype_vectors'
        )
        
        # Classification layer
        self.classifier = tf.keras.layers.Dense(n_classes)

        print(self.encoder.summary())
        print(self.decoder.summary())


    def call(self, inputs):
        # Ensure input shape is correct
        if len(inputs.shape) == 2:
            inputs = tf.reshape(inputs, [-1, 28, 28, 1])
            
        # Encode
        features = self.encoder(inputs)
        
        # Calculate distances to prototypes
        prototype_distances = list_of_distances(features, self.prototype_vectors)
        
        # Get logits
        logits = self.classifier(prototype_distances)
        
        # Decode
        decoded = self.decoder(features)
        
        return logits, decoded, features, prototype_distances

# %%
def train_step(model, optimizer, x, y, lambda_params):
    with tf.GradientTape() as tape:
        # Forward pass
        x = tf.reshape(x, [-1, 28, 28, 1])
        logits, decoded, features, prototype_distances = model(x)

        # Calculate losses
        classification_loss = tf.reduce_mean(
            tf.keras.losses.categorical_crossentropy(y, logits, from_logits=True)
        )
        x_flat = tf.reshape(x, [-1, 784])
        decoded_flat = tf.reshape(decoded, [-1, 784])
        
        reconstruction_loss = tf.reduce_mean(
            tf.keras.losses.binary_crossentropy(x_flat, decoded_flat)
        )
        
        # Prototype losses
        feature_distances = list_of_distances(model.prototype_vectors, features)
        error_1 = tf.reduce_mean(tf.reduce_min(feature_distances, axis=1))
        error_2 = tf.reduce_mean(tf.reduce_min(prototype_distances, axis=1))
        
        # Total loss
        total_loss = (lambda_params['class'] * classification_loss + 
                     lambda_params['ae'] * reconstruction_loss +
                     lambda_params['1'] * error_1 +
                     lambda_params['2'] * error_2)
    
    # Backpropagation
    gradients = tape.gradient(total_loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return {
        'classification': classification_loss,
        'reconstruction': reconstruction_loss,
        'error_1': error_1,
        'error_2': error_2,
        'total': total_loss
    }

# %%
def visualize_reconstructions(model, dataset):
    # Get multiple batches of images and select diverse samples
    sample_images = []
    for x_batch, _ in dataset.take(5):
        # Select 2 random images from each batch
        indices = tf.random.shuffle(tf.range(x_batch.shape[0]))[:2]
        sample_images.extend(tf.gather(x_batch, indices))
        if len(sample_images) >= 10:
            break
    
    sample_images = tf.stack(sample_images[:10])
    sample_images = tf.reshape(sample_images, [-1, 28, 28, 1])  # Ensure 4D shape
    
    # Reconstruct images
    _, reconstructed, _, _ = model(sample_images)
    
    # Plot results
    fig, axes = plt.subplots(2, 10, figsize=(20, 4))
    plt.suptitle('Original Images (top) vs Reconstructed Images (bottom)', y=1.05)
    
    for i in range(10):
        # Ensure proper shape for visualization
        orig_img = tf.squeeze(sample_images[i]).numpy()
        recon_img = tf.squeeze(reconstructed[i]).numpy()
        
        axes[0, i].imshow(orig_img, cmap='gray')
        axes[0, i].axis('off')
        axes[1, i].imshow(recon_img, cmap='gray')
        axes[1, i].axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
def train_model(model, train_dataset, valid_dataset, test_dataset, epochs=1500, 
                learning_rate=0.002, batch_size=250, log_dir="logs"):
    
    optimizer = tf.keras.optimizers.Adam(learning_rate)
    lambda_params = {'class': 20, 'ae': 1, '1': 1, '2': 1}
    
    for epoch in range(epochs):
        print(f"Epoch {epoch+1}/{epochs} ")
        
        # Training loop
        for x_batch, y_batch in train_dataset:
            # Apply elastic transform
            x_batch = tf.reshape(x_batch, [-1, 28, 28, 1])
            x_flat = tf.reshape(x_batch, [-1, 784])
            x_batch_elastic = batch_elastic_transform(x_flat, sigma=4, alpha=20, 
                                                    height=28, width=28)
            losses = train_step(model, optimizer, x_batch_elastic, y_batch, lambda_params)
            
        # Validation
        val_accuracy = tf.keras.metrics.CategoricalAccuracy()
        for x_val, y_val in valid_dataset:
            logits, _, _, _ = model(x_val)
            val_accuracy.update_state(y_val, logits)
            
        print(f"Validation accuracy: {val_accuracy.result():.4f}, Loss: {losses}\n")

# %%
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
# Create datasets
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(250)
valid_dataset = tf.data.Dataset.from_tensor_slices((x_test[:5000], y_test[:5000])).batch(250)
test_dataset = tf.data.Dataset.from_tensor_slices((x_test[5000:], y_test[5000:])).batch(250)
# Out:
# I0000 00:00:1733031395.038777  518456 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 602 MB memory:  -> device: 0, name: NVIDIA A40, pci bus id: 0000:01:00.0, compute capability: 8.6
# I0000 00:00:1733031395.041423  518456 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 42768 MB memory:  -> device: 1, name: NVIDIA A40, pci bus id: 0000:23:00.0, compute capability: 8.6
# I0000 00:00:1733031395.043921  518456 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 42770 MB memory:  -> device: 2, name: NVIDIA A40, pci bus id: 0000:41:00.0, compute capability: 8.6
# I0000 00:00:1733031395.046105  518456 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 42766 MB memory:  -> device: 3, name: NVIDIA A40, pci bus id: 0000:61:00.0, compute capability: 8.6
# I0000 00:00:1733031395.048194  518456 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 42768 MB memory:  -> device: 4, name: NVIDIA A40, pci bus id: 0000:81:00.0, compute capability: 8.6
# I0000 00:00:1733031395.050240  518456 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 42770 MB memory:  -> device: 5, name: NVIDIA A40, pci bus id: 0000:a1:00.0, compute capability: 8.6
# I0000 00:00:1733031395.052360  518456 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:6 with 42790 MB memory:  -> device: 6, name: NVIDIA A40, pci bus id: 0000:c1:00.0, compute capability: 8.6
# I0000 00:00:1733031395.054435  518456 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:7 with 42870 MB memory:  -> device: 7, name: NVIDIA A40, pci bus id: 0000:e1:00.0, compute capability: 8.6

# %%
# Create and train model
model = PrototypeAutoencoder(input_shape=(28, 28, 1), n_classes=10, n_prototypes=15)
# Out:
# /u/prebello/dls/lib/python3.10/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 14, 14, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 7, 7, 32)       │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 4, 4, 32)       │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 4, 4, 10)       │         2,890 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 160)            │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,706 (84.79 KB)
#  Trainable params: 21,706 (84.79 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 160)            │        25,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 4, 4, 10)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 6, 6, 32)       │         2,912 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 12, 12, 32)     │         9,248 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 14, 14, 32)     │         9,248 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 28, 28, 1)      │           289 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 47,457 (185.38 KB)
#  Trainable params: 47,457 (185.38 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
train_model(model, train_dataset, valid_dataset, test_dataset)
# Out:
# Epoch 1/1500
# I0000 00:00:1733031396.798051  518456 cuda_dnn.cc:529] Loaded cuDNN version 90400
# 2024-12-01 00:36:37.582197: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 127.89MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-12-01 00:36:37.583227: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 128.08MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-12-01 00:36:38.923586: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 97.07MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-12-01 00:37:08.383823: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-12-01 00:37:08.668789: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation accuracy: 0.8198, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.6777575016021729>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.2285607010126114>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=14.290221214294434>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=8.207448959350586>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=36.28137969970703>}
#
# Epoch 2/1500
# 2024-12-01 00:37:38.150761: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation accuracy: 0.9118, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.3752032518386841>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16014862060546875>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=14.322263717651367>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=6.4113898277282715>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=28.39786720275879>}
#
# Epoch 3/1500
# Validation accuracy: 0.9302, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.24260534346103668>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1541486233472824>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=13.624587059020996>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=5.507785797119141>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=24.138628005981445>}
#
# Epoch 4/1500
# 2024-12-01 00:38:37.316867: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation accuracy: 0.9458, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.1874133199453354>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15327462553977966>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=13.025358200073242>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=5.000993728637695>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=21.927892684936523>}
#
# Epoch 5/1500
# Validation accuracy: 0.9538, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.16704317927360535>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15336279571056366>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=12.350687980651855>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=4.701602458953857>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=20.54651641845703>}
#
# Epoch 6/1500
# Validation accuracy: 0.9596, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.14232410490512848>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16169992089271545>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=12.210078239440918>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=4.512113094329834>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=19.73037338256836>}
#
# Epoch 7/1500
# Validation accuracy: 0.9620, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.14213547110557556>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16611692309379578>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=12.158705711364746>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=4.23668098449707>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=19.404212951660156>}
#
# Epoch 8/1500
# 2024-12-01 00:40:35.675504: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation accuracy: 0.9630, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.14508207142353058>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15641212463378906>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=11.919087409973145>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=4.0554118156433105>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=19.03255271911621>}
#
# Epoch 9/1500
# Validation accuracy: 0.9666, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.15882596373558044>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16106243431568146>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=11.38233470916748>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=4.1432271003723145>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=18.863143920898438>}
#
# Epoch 10/1500
# Validation accuracy: 0.9658, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.13906404376029968>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15742284059524536>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=11.442164421081543>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=4.0578813552856445>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=18.438749313354492>}
#
# Epoch 11/1500
# Validation accuracy: 0.9670, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.15557724237442017>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15694807469844818>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=11.085562705993652>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.8679072856903076>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=18.221961975097656>}
#
# Epoch 12/1500
# Validation accuracy: 0.9658, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.11645758152008057>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1586240530014038>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=11.038565635681152>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.9866440296173096>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=17.512985229492188>}
#
# Epoch 13/1500
# Validation accuracy: 0.9682, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.11152320355176926>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16131189465522766>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=10.145654678344727>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=4.028913497924805>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=16.56634521484375>}
#
# Epoch 14/1500
# Validation accuracy: 0.9658, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.11843583732843399>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15468411147594452>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=10.264142036437988>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.9596519470214844>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=16.747194290161133>}
#
# Epoch 15/1500
# Validation accuracy: 0.9660, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.13620029389858246>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1611807495355606>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=9.942349433898926>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.896904706954956>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=16.72443962097168>}
#
# Epoch 16/1500
# 2024-12-01 00:44:32.289617: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation accuracy: 0.9676, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10312642902135849>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16454486548900604>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=10.101367950439453>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.8557724952697754>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=16.184213638305664>}
#
# Epoch 17/1500
# Validation accuracy: 0.9670, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.11554724723100662>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.157262921333313>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=10.619903564453125>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.745434045791626>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=16.833545684814453>}
#
# Epoch 18/1500
# Validation accuracy: 0.9702, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10108919441699982>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15766863524913788>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=9.35726261138916>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.7746851444244385>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=15.311399459838867>}
#
# Epoch 19/1500
# Validation accuracy: 0.9724, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.12049981951713562>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1615169644355774>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=9.28586196899414>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.807070016860962>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=15.664444923400879>}
#
# Epoch 20/1500
# Validation accuracy: 0.9706, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.11093935370445251>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15803076326847076>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=8.749917030334473>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.618265390396118>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=14.744999885559082>}
#
# Epoch 21/1500
# Validation accuracy: 0.9682, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10015325248241425>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16476422548294067>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=9.597640991210938>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.6913979053497314>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=15.456868171691895>}
#
# Epoch 22/1500
# Validation accuracy: 0.9698, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09820276498794556>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15927273035049438>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=9.103196144104004>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.650217056274414>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=14.876741409301758>}
#
# Epoch 23/1500
# Validation accuracy: 0.9746, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08680228143930435>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15730106830596924>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=9.187448501586914>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.5257747173309326>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=14.60657024383545>}
#
# Epoch 24/1500
# Validation accuracy: 0.9718, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10010102391242981>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15908269584178925>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=8.69373607635498>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.752169370651245>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=14.607008934020996>}
#
# Epoch 25/1500
# Validation accuracy: 0.9710, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.1248217523097992>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1619132161140442>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=8.36465072631836>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.712555170059204>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=14.735553741455078>}
#
# Epoch 26/1500
# Validation accuracy: 0.9742, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09663194417953491>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16198627650737762>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=8.745485305786133>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.5780208110809326>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=14.418131828308105>}
#
# Epoch 27/1500
# Validation accuracy: 0.9694, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0871238261461258>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16089631617069244>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=8.387253761291504>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.5169527530670166>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=13.807579040527344>}
#
# Epoch 28/1500
# Validation accuracy: 0.9710, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10473012179136276>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16003015637397766>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=8.31861400604248>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.44953989982605>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=14.022786140441895>}
#
# Epoch 29/1500
# Validation accuracy: 0.9740, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.11368249356746674>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16019903123378754>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=8.631719589233398>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.4410319328308105>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=14.506601333618164>}
#
# Epoch 30/1500
# Validation accuracy: 0.9750, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.1119464635848999>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15808062255382538>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.902714729309082>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.5123677253723145>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=13.812091827392578>}
#
# Epoch 31/1500
# Validation accuracy: 0.9760, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06317346543073654>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16046908497810364>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=9.013083457946777>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.2434401512145996>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=13.680461883544922>}
#
# Epoch 32/1500
# 2024-12-01 00:52:23.641654: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation accuracy: 0.9736, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09177093952894211>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15970608592033386>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=8.85696792602539>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.3008594512939453>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=14.152952194213867>}
#
# Epoch 33/1500
# Validation accuracy: 0.9730, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10581207275390625>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15730828046798706>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.553914546966553>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.3360023498535156>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=13.163466453552246>}
#
# Epoch 34/1500
# Validation accuracy: 0.9720, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08279801905155182>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15703225135803223>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.50618839263916>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.225525379180908>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=12.544706344604492>}
#
# Epoch 35/1500
# Validation accuracy: 0.9758, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10480432212352753>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1567770093679428>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=8.865976333618164>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.1797850131988525>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=14.298624038696289>}
#
# Epoch 36/1500
# Validation accuracy: 0.9696, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07579697668552399>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1591942459344864>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.18972635269165>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.157708168029785>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=12.022568702697754>}
#
# Epoch 37/1500
# Validation accuracy: 0.9762, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.1072956770658493>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15702305734157562>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=8.064955711364746>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.247009038925171>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=13.614901542663574>}
#
# Epoch 38/1500
# Validation accuracy: 0.9726, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09542019665241241>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15375369787216187>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=8.337854385375977>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.2233989238739014>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=13.623411178588867>}
#
# Epoch 39/1500
# Validation accuracy: 0.9772, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07346062362194061>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1571701020002365>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.424851417541504>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.1463217735290527>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=12.197555541992188>}
#
# Epoch 40/1500
# Validation accuracy: 0.9782, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10279063135385513>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16453681886196136>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=8.29019546508789>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.1754958629608154>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=13.686040878295898>}
#
# Epoch 41/1500
# Validation accuracy: 0.9746, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09339364618062973>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.161698579788208>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.540031909942627>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.198906660079956>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=12.768509864807129>}
#
# Epoch 42/1500
# Validation accuracy: 0.9774, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07610403746366501>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15832093358039856>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.553700923919678>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.075972080230713>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=12.310073852539062>}
#
# Epoch 43/1500
# Validation accuracy: 0.9776, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09041594713926315>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1591178923845291>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.696347713470459>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=3.0601065158843994>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=12.723891258239746>}
#
# Epoch 44/1500
# Validation accuracy: 0.9762, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06716220825910568>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1601087749004364>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.799496173858643>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.824516534805298>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.127365112304688>}
#
# Epoch 45/1500
# Validation accuracy: 0.9792, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10285980254411697>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15774954855442047>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.627631187438965>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.818641185760498>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=12.661218643188477>}
#
# Epoch 46/1500
# Validation accuracy: 0.9794, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.1062561571598053>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1594301462173462>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.7744646072387695>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.914652109146118>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.973669052124023>}
#
# Epoch 47/1500
# Validation accuracy: 0.9774, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08640048652887344>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15907877683639526>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.361459255218506>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.828437566757202>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.076985359191895>}
#
# Epoch 48/1500
# Validation accuracy: 0.9764, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08381766825914383>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15862049162387848>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.32780122756958>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.8224968910217285>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.985271453857422>}
#
# Epoch 49/1500
# Validation accuracy: 0.9784, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07630518823862076>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15733429789543152>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.61048698425293>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.835165023803711>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=12.129090309143066>}
#
# Epoch 50/1500
# Validation accuracy: 0.9790, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09523368626832962>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15807127952575684>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.9889631271362305>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.8227086067199707>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=10.87441635131836>}
#
# Epoch 51/1500
# Validation accuracy: 0.9770, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.13717345893383026>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15838618576526642>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.867193222045898>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.8469908237457275>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=12.616039276123047>}
#
# Epoch 52/1500
# Validation accuracy: 0.9754, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08873125165700912>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1619747132062912>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.950938701629639>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.769251823425293>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=10.656789779663086>}
#
# Epoch 53/1500
# Validation accuracy: 0.9790, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09149881452322006>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1571435183286667>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.967456340789795>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.633565664291382>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.588142395019531>}
#
# Epoch 54/1500
# Validation accuracy: 0.9772, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06139128655195236>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16176392138004303>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.080406665802002>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.6429145336151123>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.112911224365234>}
#
# Epoch 55/1500
# Validation accuracy: 0.9776, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07398054748773575>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15959568321704865>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.14045524597168>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.6899125576019287>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.469574928283691>}
#
# Epoch 56/1500
# Validation accuracy: 0.9780, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09207148849964142>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15842318534851074>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.000328063964844>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.7258338928222656>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=10.726015090942383>}
#
# Epoch 57/1500
# Validation accuracy: 0.9814, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08481553941965103>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15747177600860596>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.434496879577637>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.6628904342651367>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.951169967651367>}
#
# Epoch 58/1500
# Validation accuracy: 0.9802, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09568502008914948>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15885664522647858>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.491340637207031>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.9105799198150635>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.474477767944336>}
#
# Epoch 59/1500
# Validation accuracy: 0.9790, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0942833349108696>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1608767807483673>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.318483829498291>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.7878754138946533>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=10.152902603149414>}
#
# Epoch 60/1500
# Validation accuracy: 0.9798, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06080378219485283>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15678566694259644>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.0987958908081055>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.6773509979248047>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=10.149007797241211>}
#
# Epoch 61/1500
# Validation accuracy: 0.9782, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07908611744642258>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15917593240737915>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.913393974304199>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.633589506149292>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.287881851196289>}
#
# Epoch 62/1500
# Validation accuracy: 0.9778, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09719511866569519>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15936996042728424>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.123541831970215>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.6749954223632812>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=10.901809692382812>}
#
# Epoch 63/1500
# Validation accuracy: 0.9804, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10503094643354416>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.158430814743042>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.413539409637451>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.6104280948638916>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.2830171585083>}
#
# Epoch 64/1500
# 2024-12-01 01:08:01.485603: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation accuracy: 0.9752, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07504132390022278>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15688353776931763>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.40032434463501>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.7209181785583496>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=9.778952598571777>}
#
# Epoch 65/1500
# Validation accuracy: 0.9782, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10730903595685959>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1613720953464508>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.5627264976501465>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.5152664184570312>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.38554573059082>}
#
# Epoch 66/1500
# Validation accuracy: 0.9796, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10879290848970413>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16239798069000244>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.27935791015625>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.6016056537628174>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.219220161437988>}
#
# Epoch 67/1500
# Validation accuracy: 0.9816, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.1283767819404602>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16049471497535706>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=8.433514595031738>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.674478530883789>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=13.836023330688477>}
#
# Epoch 68/1500
# Validation accuracy: 0.9774, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0911693125963211>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16183705627918243>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.78867244720459>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.620363235473633>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.394258499145508>}
#
# Epoch 69/1500
# Validation accuracy: 0.9790, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07500064373016357>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15693210065364838>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.357651710510254>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.453805446624756>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=10.468402862548828>}
#
# Epoch 70/1500
# Validation accuracy: 0.9788, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09358751028776169>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16116033494472504>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.3588995933532715>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.7030458450317383>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=10.094856262207031>}
#
# Epoch 71/1500
# Validation accuracy: 0.9774, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07398966699838638>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15684103965759277>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.499686241149902>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.5676045417785645>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=10.703924179077148>}
#
# Epoch 72/1500
# Validation accuracy: 0.9784, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07983097434043884>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16394560039043427>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.612399101257324>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.3928589820861816>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.765823364257812>}
#
# Epoch 73/1500
# Validation accuracy: 0.9762, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10254926234483719>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16256408393383026>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.814516067504883>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.312211036682129>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.340276718139648>}
#
# Epoch 74/1500
# Validation accuracy: 0.9762, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07027716189622879>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15941616892814636>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.4940104484558105>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.5681381225585938>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.627107620239258>}
#
# Epoch 75/1500
# Validation accuracy: 0.9774, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09039879590272903>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16175730526447296>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.654276371002197>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.4411675930023193>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.065177917480469>}
#
# Epoch 76/1500
# Validation accuracy: 0.9782, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.086817666888237>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15932336449623108>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.199109077453613>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.523512363433838>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.618297576904297>}
#
# Epoch 77/1500
# Validation accuracy: 0.9786, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08152081072330475>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15722768008708954>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.375312328338623>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.370110273361206>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=9.533066749572754>}
#
# Epoch 78/1500
# Validation accuracy: 0.9770, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10222327709197998>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15496720373630524>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.452741622924805>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.478853225708008>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.131027221679688>}
#
# Epoch 79/1500
# Validation accuracy: 0.9774, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.083600252866745>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1611098349094391>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.1923828125>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.358915328979492>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=9.38441276550293>}
#
# Epoch 80/1500
# Validation accuracy: 0.9780, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09075583517551422>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1597156673669815>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.6198225021362305>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.337242364883423>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=9.931897163391113>}
#
# Epoch 81/1500
# Validation accuracy: 0.9774, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.11390937119722366>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16018012166023254>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.071101188659668>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.3710567951202393>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=10.880525588989258>}
#
# Epoch 82/1500
# Validation accuracy: 0.9770, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07631302624940872>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15888701379299164>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.953192710876465>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.295351982116699>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=9.93369197845459>}
#
# Epoch 83/1500
# Validation accuracy: 0.9784, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.11760769039392471>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1602955311536789>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.644163608551025>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.2144980430603027>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=10.371110916137695>}
#
# Epoch 84/1500
# Validation accuracy: 0.9780, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10262222588062286>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15733520686626434>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.323829650878906>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.4996275901794434>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.03323745727539>}
#
# Epoch 85/1500
# Validation accuracy: 0.9784, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09946511685848236>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16181711852550507>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.150778770446777>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.340602159500122>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=9.642499923706055>}
#
# Epoch 86/1500
# Validation accuracy: 0.9794, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07817884534597397>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15954968333244324>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.840697765350342>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.2467904090881348>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=9.810615539550781>}
#
# Epoch 87/1500
# Validation accuracy: 0.9766, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09164237976074219>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16241714358329773>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=7.052762508392334>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.2879114151000977>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=11.335938453674316>}
#
# Epoch 88/1500
# Validation accuracy: 0.9794, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06787077337503433>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15756569802761078>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.267853736877441>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.2003676891326904>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=8.983202934265137>}
#
# Epoch 89/1500
# Validation accuracy: 0.9796, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07840315997600555>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16224364936351776>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.925612449645996>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.223210334777832>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=9.879129409790039>}
#
# Epoch 90/1500
# Validation accuracy: 0.9788, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0869135931134224>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15968148410320282>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.967697620391846>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.222611427307129>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=10.088262557983398>}
#
# Epoch 91/1500
# Validation accuracy: 0.9782, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06615409255027771>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16041867434978485>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.495422840118408>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.2404966354370117>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=9.219419479370117>}
#
# Epoch 92/1500
# Validation accuracy: 0.9784, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06135038286447525>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16071777045726776>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.791548728942871>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.3188424110412598>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=9.498116493225098>}
#
# Epoch 93/1500
# Validation accuracy: 0.9736, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06760451197624207>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16239099204540253>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.475969314575195>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.154776096343994>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=9.14522647857666>}
#
# Epoch 94/1500
# Validation accuracy: 0.9792, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0642852708697319>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.165094792842865>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.499244213104248>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.235888957977295>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=10.185934066772461>}
#
# Epoch 95/1500
# Validation accuracy: 0.9770, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07534970343112946>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15891920030117035>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=4.816884994506836>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.1712396144866943>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=8.654037475585938>}
#
# Epoch 96/1500
# Validation accuracy: 0.9790, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09750109910964966>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16172510385513306>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.113232135772705>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.258035898208618>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=10.483015060424805>}
#
# Epoch 97/1500
# Validation accuracy: 0.9776, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07864677160978317>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1611790955066681>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.257663249969482>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.152845621109009>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=9.144623756408691>}
#
# Epoch 98/1500
# Validation accuracy: 0.9780, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10442989319562912>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1603080779314041>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=4.646388053894043>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.0540037155151367>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=8.949297904968262>}
#
# Epoch 99/1500
# Validation accuracy: 0.9794, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0961591973900795>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16012518107891083>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.29133939743042>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.314736843109131>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=10.689386367797852>}
#
# Epoch 100/1500
# Validation accuracy: 0.9770, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08841138333082199>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16006581485271454>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.262369155883789>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.277271270751953>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=9.467933654785156>}
#
# Epoch 101/1500
# Validation accuracy: 0.9774, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07239360362291336>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16104207932949066>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.5169358253479>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.3187270164489746>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=9.444576263427734>}
#
# Epoch 102/1500
# Validation accuracy: 0.9794, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06704436242580414>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1583949625492096>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.0716681480407715>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.1992287635803223>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=9.770179748535156>}
#
# Epoch 103/1500
# Validation accuracy: 0.9770, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06831467151641846>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16175921261310577>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=5.600362300872803>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.093587636947632>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=9.222002983093262>}
#
# Epoch 104/1500
# Validation accuracy: 0.9796, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09103452414274216>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.159398153424263>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=6.549685001373291>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=2.0685741901397705>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=10.598347663879395>}
#
# Epoch 105/1500
# ...
#
# Epoch 1465/1500
# Validation accuracy: 0.9770, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08745428919792175>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16062387824058533>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.914602041244507>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.4186794757843018>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=7.2429914474487305>}
#
# Epoch 1466/1500
# Validation accuracy: 0.9794, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07915055751800537>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16230390965938568>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.578662157058716>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.6445214748382568>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=6.968499183654785>}
#
# Epoch 1467/1500
# Validation accuracy: 0.9836, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06990393251180649>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1565363109111786>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=4.07080078125>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.5252693891525269>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=7.1506853103637695>}
#
# Epoch 1468/1500
# Validation accuracy: 0.9780, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07654964923858643>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15529632568359375>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.0188889503479004>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.544006586074829>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=6.249184608459473>}
#
# Epoch 1469/1500
# Validation accuracy: 0.9746, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08473989367485046>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15890948474407196>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=2.045408010482788>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.4847331047058105>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=5.383848190307617>}
#
# Epoch 1470/1500
# Validation accuracy: 0.9784, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.058859292417764664>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16093315184116364>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=2.8799335956573486>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.5658551454544067>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=5.783907890319824>}
#
# Epoch 1471/1500
# Validation accuracy: 0.9812, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06861661374568939>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15790580213069916>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.9140584468841553>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.6114405393600464>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=7.055737495422363>}
#
# Epoch 1472/1500
# Validation accuracy: 0.9778, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07599435746669769>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16070885956287384>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.5310938358306885>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.4408345222473145>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=6.652524471282959>}
#
# Epoch 1473/1500
# Validation accuracy: 0.9790, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08657191693782806>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1600566804409027>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.671773672103882>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.5547186136245728>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=7.117987155914307>}
#
# Epoch 1474/1500
# Validation accuracy: 0.9810, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.12770432233810425>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16131582856178284>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=2.387746572494507>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.6574252843856812>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=6.7605743408203125>}
#
# Epoch 1475/1500
# Validation accuracy: 0.9790, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06702870875597>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15996846556663513>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.3332645893096924>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.5080879926681519>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=6.34189510345459>}
#
# Epoch 1476/1500
# Validation accuracy: 0.9794, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09046896547079086>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16109545528888702>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.8063111305236816>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.4930384159088135>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=7.269824028015137>}
#
# Epoch 1477/1500
# Validation accuracy: 0.9792, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08438980579376221>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15636533498764038>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.3334152698516846>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.3632150888442993>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=6.540791988372803>}
#
# Epoch 1478/1500
# Validation accuracy: 0.9754, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09865717589855194>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15838487446308136>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=2.806905508041382>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.6370854377746582>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=6.57551908493042>}
#
# Epoch 1479/1500
# Validation accuracy: 0.9796, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10263711214065552>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16185212135314941>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=2.497943162918091>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.688928246498108>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=6.401465892791748>}
#
# Epoch 1480/1500
# Validation accuracy: 0.9794, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09689181298017502>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1596459001302719>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.8282227516174316>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.5621681213378906>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=7.487873077392578>}
#
# Epoch 1481/1500
# Validation accuracy: 0.9760, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09687358886003494>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16098974645137787>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.8025925159454346>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.5139538049697876>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=7.415007591247559>}
#
# Epoch 1482/1500
# Validation accuracy: 0.9798, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.12814970314502716>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15889544785022736>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.545797824859619>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.6020818948745728>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=7.869769096374512>}
#
# Epoch 1483/1500
# Validation accuracy: 0.9790, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.0820847898721695>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15959374606609344>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.23435115814209>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.6066977977752686>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=6.642338752746582>}
#
# Epoch 1484/1500
# Validation accuracy: 0.9784, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08871206641197205>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16001775860786438>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.7818167209625244>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.5151616334915161>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=7.231237411499023>}
#
# Epoch 1485/1500
# Validation accuracy: 0.9796, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.10102789103984833>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16071878373622894>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.242086172103882>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.4632270336151123>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=6.886590003967285>}
#
# Epoch 1486/1500
# Validation accuracy: 0.9808, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06959570944309235>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1590723991394043>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=2.1647069454193115>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.624964714050293>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=5.340658187866211>}
#
# Epoch 1487/1500
# Validation accuracy: 0.9824, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.06062562018632889>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15764902532100677>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=2.379591941833496>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.5324405431747437>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=5.282194137573242>}
#
# Epoch 1488/1500
# Validation accuracy: 0.9794, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08618586510419846>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.158815398812294>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=2.624112844467163>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.4208604097366333>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=5.927505970001221>}
#
# Epoch 1489/1500
# Validation accuracy: 0.9804, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.1055617481470108>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1602233499288559>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=2.4716782569885254>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.3911799192428589>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=6.134316444396973>}
#
# Epoch 1490/1500
# Validation accuracy: 0.9780, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07618822157382965>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15896297991275787>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=4.277752876281738>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.5064629316329956>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=7.466943264007568>}
#
# Epoch 1491/1500
# Validation accuracy: 0.9774, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07026313990354538>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15681014955043793>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.9255452156066895>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.2916409969329834>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=6.77925968170166>}
#
# Epoch 1492/1500
# Validation accuracy: 0.9798, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08959085494279861>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.16098202764987946>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.074026584625244>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.5048480033874512>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=6.531673908233643>}
#
# Epoch 1493/1500
# Validation accuracy: 0.9800, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07911032438278198>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15776844322681427>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=2.3823726177215576>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.4815524816513062>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=5.60390043258667>}
#
# Epoch 1494/1500
# Validation accuracy: 0.9796, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09816252440214157>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1586875468492508>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=2.5512146949768066>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.6594480276107788>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=6.332601070404053>}
#
# Epoch 1495/1500
# Validation accuracy: 0.9800, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.12977252900600433>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15701551735401154>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=2.6626555919647217>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.3670161962509155>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=6.782138347625732>}
#
# Epoch 1496/1500
# Validation accuracy: 0.9792, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07804073393344879>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15577934682369232>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=2.9006311893463135>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.3798798322677612>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=5.997105121612549>}
#
# Epoch 1497/1500
# Validation accuracy: 0.9732, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.1104746088385582>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.1617737114429474>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=2.739044189453125>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.548901081085205>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=6.659211158752441>}
#
# Epoch 1498/1500
# Validation accuracy: 0.9780, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.08231739699840546>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15843527019023895>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=3.7714076042175293>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.4720529317855835>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=7.048243999481201>}
#
# Epoch 1499/1500
# Validation accuracy: 0.9782, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.09060771763324738>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15736638009548187>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=2.612273693084717>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.5148407220840454>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=6.096634864807129>}
#
# Epoch 1500/1500
# Validation accuracy: 0.9782, Loss: {'classification': <tf.Tensor: shape=(), dtype=float32, numpy=0.07600878924131393>, 'reconstruction': <tf.Tensor: shape=(), dtype=float32, numpy=0.15852312743663788>, 'error_1': <tf.Tensor: shape=(), dtype=float32, numpy=2.693035364151001>, 'error_2': <tf.Tensor: shape=(), dtype=float32, numpy=1.3055042028427124>, 'total': <tf.Tensor: shape=(), dtype=float32, numpy=5.677238464355469>}

# %%
visualize_reconstructions(model, train_dataset)

# %%
# After training is complete
model.save("mnist_prototype_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
def visualize_weight_matrix(model):
    # Get the weights from the classifier layer (prototype to class weights)
    weights = model.classifier.get_weights()[0]  # Shape: [n_prototypes, n_classes]
    
    # Create figure
    fig, ax = plt.subplots(figsize=(12, 8))
    
    # Display the weight matrix
    im = ax.imshow(weights, cmap='RdBu_r')
    
    # Set labels
    class_names = [str(i) for i in range(10)]  # MNIST digits 0-9
    
    # Add colorbar
    plt.colorbar(im)
    
    # Configure axes
    ax.set_xticks(np.arange(len(class_names)))
    ax.set_xticklabels(class_names)
    ax.set_xlabel('Digit Classes')
    ax.set_ylabel('Prototypes')
    
    # Add numbers in cells
    for i in range(weights.shape[0]):
        for j in range(weights.shape[1]):
            text = ax.text(j, i, f'{weights[i, j]:.2f}',
                         ha="center", va="center", 
                         color="black" if abs(weights[i, j]) < 10 else "white")
    
    plt.title("Prototype-to-Class Weight Matrix")
    plt.tight_layout()
    plt.show()

# %%
# After training the model
visualize_weight_matrix(model)

# %%
def visualize_image_class_weights(model, dataset):
    # Get one sample image from each class
    images_by_class = [[] for _ in range(10)]
    for x_batch, y_batch in dataset:
        y_labels = tf.argmax(y_batch, axis=1)
        for img, label in zip(x_batch, y_labels):
            images_by_class[label.numpy()].append(img)
        if all(len(c) > 0 for c in images_by_class):
            break
    
    # Select first image from each class
    sample_images = [class_images[0] for class_images in images_by_class]
    sample_images = tf.stack(sample_images)
    
    # Get logits through the model
    logits, _, features, _ = model(sample_images)
    
    # Create figure with proper sizing
    fig = plt.figure(figsize=(15, 10))
    gs = plt.GridSpec(2, 1, height_ratios=[4, 1])
    
    # Plot weight matrix
    ax_weights = fig.add_subplot(gs[0])
    im = ax_weights.imshow(logits.numpy(), cmap='RdBu_r')
    plt.colorbar(im)
    
    # Add weight values in cells
    for i in range(logits.shape[0]):
        for j in range(logits.shape[1]):
            text_color = 'white' if abs(logits[i, j]) > 10 else 'black'
            ax_weights.text(j, i, f'{logits[i, j]:.2f}',
                          ha='center', va='center', color=text_color)
    
    # Plot sample digits on right side
    ax_images = fig.add_subplot(gs[1])
    for i in range(10):
        ax_images.imshow(sample_images[i], 
                        extent=[i-0.5, i+0.5, 0, 1],
                        cmap='gray')
    
    # Configure axes
    ax_weights.set_xticks(range(10))
    ax_weights.set_xticklabels(range(10))
    ax_weights.set_ylabel('Input Images')
    ax_weights.set_xlabel('Digit Classes')
    ax_images.set_xticks([])
    ax_images.set_yticks([])
    
    plt.suptitle('Image-to-Class Weight Matrix')
    plt.tight_layout()
    plt.show()

# %%
visualize_image_class_weights(model, train_dataset)
